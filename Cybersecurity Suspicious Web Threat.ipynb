# %% [markdown]
# ## Web Traffic Analyse
#
# A dataset collected by the AWS CloudWatch, its aims to identifies the potential threat of attacks and detection of suspicious activities of anomalous  patterns in web servers.
#
# ### Data entries
#
# * bytes_in: Bytes received by the server.
#
# * bytes_out: Bytes sent from the server.
#
# * creation_time: Timestamp of when the record was created.
#
# * end_time: Timestamp of when the connection ended.
#
# * src_ip: Source IP address.
#
# * src_ip_country_code: Country code of the source IP.
#
# * protocol: Protocol used in the connection.
#
# * response.code: HTTP response code.
#
# * dst_port: Destination port on the server.
#
# * dst_ip: Destination IP address.
#
# * rule_names: Name of the rule that identified the traffic as suspicious.
#
# * observation_name: Observations associated with the traffic.
#
# * source.meta: Metadata related to the source.
#
# * source.name: Name of the traffic source.
#
# * time: Timestamp of the detected event.
#
# * detection_types: Type of detection applied.
#
#
# Provided here: [Cybersecurity: Suspicious Web Threat Interactions](https://www.kaggle.com/datasets/jancsg/cybersecurity-suspicious-web-threat-interactions)

# %%
import pandas as pd

cloud = pd.read_csv('files/CloudWatch_Traffic_Web_Attack.csv')
cloud
# Out:
#      bytes_in  bytes_out         creation_time              end_time  \
# 0        5602      12990  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 1       30912      18186  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 2       28506      13468  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 3       30546      14278  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# 4        6526      13892  2024-04-25T23:00:00Z  2024-04-25T23:10:00Z
# ..        ...        ...                   ...                   ...
# 277     41336      13180  2024-04-26T09:50:00Z  2024-04-26T10:00:00Z
# 278      3638       3190  2024-04-26T09:50:00Z  2024-04-26T10:00:00Z
# 279  25207794    1561220  2024-04-26T09:50:00Z  2024-04-26T10:00:00Z
# 280      5736      12114  2024-04-26T09:50:00Z  2024-04-26T10:00:00Z
# 281      9032       5862  2024-04-26T09:50:00Z  2024-04-26T10:00:00Z
#
#               src_ip src_ip_country_code protocol  response.code  dst_port  \
# ...

# %% [markdown]
# ### Bytes Size Transfer

# %%
cloud['bytes_in'].mean()
# Out:
# 1199390.1914893617

# %%
cloud['bytes_out'].mean()
# Out:
# 84554.29078014185

# %% [markdown]
# ### Targeted Countries
#
# Accessing which countries are mostly targeted and the number of detections of suspicious attacks.

# %%
cloud['src_ip_country_code'].describe()
# Out:
# count     282
# unique      7
# top        US
# freq      113
# Name: src_ip_country_code, dtype: object

# %%
cloud['src_ip_country_code'].value_counts()
# Out:
# US    113
# CA     72
# DE     28
# AT     21
# NL     18
# AE     16
# IL     14
# Name: src_ip_country_code, dtype: int64

# %%
cloud['src_ip_country_code'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Country Overview
#
# Countries that has detected suspicious activities.
# * United Arab Emirates
# * Austria
# * Canada
# * Denmark
# * Netherlands
# * Israel
# * United State
#
# The most number of detections and suspicious activities are identified from the US consisting with the highest total of 113 occurance followed by Canada of 72.
